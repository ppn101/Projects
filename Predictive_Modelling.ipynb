# %% [markdown]
# <a href="https://colab.research.google.com/github/ppn101/Projects/blob/main/Predictive_Modelling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing the required libraries for performing data wrangling.
import pandas as pd
import numpy as np
import datetime

# %%
#Accesing the file and storing it as a csv for further operations - Gold Reserves in Tonnes.
dfgt = pd.read_csv("/content/drive/MyDrive/Predictive_Project/gold_reserves_(tonnes).csv")
dfgt.head(3)
# Out:
#                     Country      2001      2002      2003      2004      2005  \
# 0  United States of America  8,149.05  8,149.05  8,134.94  8,136.18  8,135.07
# 1                   Germany  3,456.56  3,445.80  3,439.52  3,433.24  3,427.79
# 2                    France  3,024.63  3,024.70  3,024.66  2,985.29  2,825.79
#
#        2006      2007      2008      2009  ...      2012      2013      2014  \
# 0  8,133.46  8,133.46  8,133.46  8,133.46  ...  8,133.46  8,133.46  8,133.46
# 1  3,422.51  3,417.37  3,412.58  3,406.77  ...  3,391.34  3,387.14  3,384.19
# 2  2,719.76  2,603.06  2,492.15  2,435.41  ...  2,435.38  2,435.38  2,435.38
#
#        2015      2016      2017      2018      2019      2020      2021
# 0  8,133.46  8,133.46  8,133.46  8,133.46  8,133.46  8,133.46  8,133.47
# 1  3,380.98  3,377.94  3,373.64  3,369.72  3,366.49  3,362.45  3,359.09
# 2  2,435.63  2,435.85  2,436.01  2,436.04  2,436.01  2,436.19  2,436.47
#
# [3 rows x 22 columns]

# %%
#Checking the datatypes of each column.
dfgt.dtypes
# Out:
# Country    object
# 2001       object
# 2002       object
# 2003       object
# 2004       object
# 2005       object
# 2006       object
# 2007       object
# 2008       object
# 2009       object
# 2010       object
# 2011       object
# 2012       object
# 2013       object
# 2014       object
# 2015       object
# 2016       object
# 2017       object
# 2018       object
# 2019       object
# 2020       object
# 2021       object
# dtype: object

# %%
#Counting if there are more than 1 entry for each countryname for any given year.
dfgt["Country"].value_counts()
# Out:
# United States of America    1
# Eritrea                     1
# Mozambique                  1
# Yemen                       1
# Trinidad and Tobago         1
#                            ..
# Kazakhstan                  1
# Pakistan                    1
# Denmark                     1
# Egypt                       1
# Uzbekistan                  1
# Name: Country, Length: 123, dtype: int64

# %%
#replacing textual values with numerical values for further analysis at a quantitative level.
dfgt.replace(to_replace = 'AWAITED', value = 0, inplace = True)

# %%
dfgt
# Out:
#                       Country      2001      2002      2003      2004  \
# 0    United States of America  8,149.05  8,149.05  8,134.94  8,136.18
# 1                     Germany  3,456.56  3,445.80  3,439.52  3,433.24
# 2                      France  3,024.63  3,024.70  3,024.66  2,985.29
# 3                       Italy  2,451.84  2,451.84  2,451.84  2,451.84
# 4                 Switzerland  2,198.48  1,916.68  1,633.29  1,354.29
# ..                        ...       ...       ...       ...       ...
# 118                Azerbaijan         0         0         0         0
# 119                   Croatia         0         0         0         0
# 120               Afghanistan         0         0         0         0
# 121                      Iraq         0         0         0      5.87
# 122                Uzbekistan         0         0         0         0
#
#          2005      2006      2007      2008      2009  ...      2012  \
# ...

# %%
#replacing null values with 0 before performing quantitative analysis.
dfgt.fillna(value = 0, axis = 1, inplace = True)

# %%
#returning the updated dataframe to check the changes made by the previous code.
dfgt
# Out:
#                       Country      2001      2002      2003      2004  \
# 0    United States of America  8,149.05  8,149.05  8,134.94  8,136.18
# 1                     Germany  3,456.56  3,445.80  3,439.52  3,433.24
# 2                      France  3,024.63  3,024.70  3,024.66  2,985.29
# 3                       Italy  2,451.84  2,451.84  2,451.84  2,451.84
# 4                 Switzerland  2,198.48  1,916.68  1,633.29  1,354.29
# ..                        ...       ...       ...       ...       ...
# 118                Azerbaijan         0         0         0         0
# 119                   Croatia         0         0         0         0
# 120               Afghanistan         0         0         0         0
# 121                      Iraq         0         0         0      5.87
# 122                Uzbekistan         0         0         0         0
#
#          2005      2006      2007      2008      2009  ...      2012  \
# ...

# %%
#Checking if there are remaning null values in the dataframe.
dfgt.isnull().sum()
# Out:
# Country    0
# 2001       0
# 2002       0
# 2003       0
# 2004       0
# 2005       0
# 2006       0
# 2007       0
# 2008       0
# 2009       0
# 2010       0
# 2011       0
# 2012       0
# 2013       0
# 2014       0
# 2015       0
# 2016       0
# 2017       0
# 2018       0
# 2019       0
# 2020       0
# 2021       0
# dtype: int64

# %%
#Performing data transformation on Table - Gold Reserve in Tonnes
dfgt = pd.melt(dfgt, id_vars = ["Country"], var_name = "year", value_name = "Reserves(Ton)")
dfgt
# Out:
#                        Country  year Reserves(Ton)
# 0     United States of America  2001      8,149.05
# 1                      Germany  2001      3,456.56
# 2                       France  2001      3,024.63
# 3                        Italy  2001      2,451.84
# 4                  Switzerland  2001      2,198.48
# ...                        ...   ...           ...
# 2578                Azerbaijan  2021             0
# 2579                   Croatia  2021             0
# 2580               Afghanistan  2021         21.87
# 2581                      Iraq  2021         96.42
# 2582                Uzbekistan  2021        362.04
#
# [2583 rows x 3 columns]

# %%
#Saving the gold reserves in tonnes csv in the directory.
dfgt.to_csv("dfgt.csv", index = False)

# %%
#Accesing the file and storing it as a csv for further operations - Gold Reserves in Tonnes
dfgm = pd.read_csv("/content/drive/MyDrive/Predictive_Project/gold_reserves_(us$_millions).csv")
dfgm.head(3)
# Out:
#                     Country       2001       2002        2003        2004  \
# 0  United States of America  72,443.00  90,966.40  108,868.72  113,947.00
# 1                   Germany  30,728.00  38,464.90   46,030.59   48,082.40
# 2                    France  26,888.24  33,764.16   40,478.65   41,808.89
#
#          2005        2006        2007        2008        2009  ...  \
# 0  134,175.43  165,267.30  218,024.71  227,438.67  284,380.05  ...
# 1   56,536.19   69,543.38   91,605.78   95,427.23  119,114.96  ...
# 2   46,607.07   55,263.98   69,777.37   69,688.72   85,152.34  ...
#
#          2012        2013        2014        2015        2016        2017  \
# 0  433,434.47  314,975.46  315,367.71  277,188.86  299,651.62  337,595.11
# 1  180,725.51  131,170.05  131,218.83  115,224.12  124,449.32  140,029.61
# 2  129,782.25   94,312.35   94,429.80   83,006.48   89,741.16  101,111.12
#
#          2018        2019        2020        2021
# ...

# %%
dfgm.dtypes
# Out:
# Country    object
# 2001       object
# 2002       object
# 2003       object
# 2004       object
# 2005       object
# 2006       object
# 2007       object
# 2008       object
# 2009       object
# 2010       object
# 2011       object
# 2012       object
# 2013       object
# 2014       object
# 2015       object
# 2016       object
# 2017       object
# 2018       object
# 2019       object
# 2020       object
# 2021       object
# dtype: object

# %%
dfgm["Country"].value_counts()
# Out:
# United States of America    1
# Eritrea                     1
# Mozambique                  1
# Yemen                       1
# Trinidad and Tobago         1
#                            ..
# Kazakhstan                  1
# Pakistan                    1
# Denmark                     1
# Egypt                       1
# Uzbekistan                  1
# Name: Country, Length: 123, dtype: int64

# %%
dfgm.replace(to_replace = 'AWAITED', value = 0, inplace = True)
dfgm
# Out:
#                       Country       2001       2002        2003        2004  \
# 0    United States of America  72,443.00  90,966.40  108,868.72  113,947.00
# 1                     Germany  30,728.00  38,464.90   46,030.59   48,082.40
# 2                      France  26,888.24  33,764.16   40,478.65   41,808.89
# 3                       Italy  21,796.22  27,369.43   32,812.57   34,337.91
# 4                 Switzerland  19,543.95  21,395.61   21,858.03   18,966.77
# ..                        ...        ...        ...         ...         ...
# 118                Azerbaijan          0          0           0           0
# 119                   Croatia          0          0           0           0
# 120               Afghanistan          0          0           0           0
# 121                      Iraq          0          0           0       82.15
# 122                Uzbekistan          0          0           0           0
#
# ...

# %%
dfgm.fillna(value = 0, axis = 1, inplace = True)
dfgm
# Out:
#                       Country       2001       2002        2003        2004  \
# 0    United States of America  72,443.00  90,966.40  108,868.72  113,947.00
# 1                     Germany  30,728.00  38,464.90   46,030.59   48,082.40
# 2                      France  26,888.24  33,764.16   40,478.65   41,808.89
# 3                       Italy  21,796.22  27,369.43   32,812.57   34,337.91
# 4                 Switzerland  19,543.95  21,395.61   21,858.03   18,966.77
# ..                        ...        ...        ...         ...         ...
# 118                Azerbaijan          0          0           0           0
# 119                   Croatia          0          0           0           0
# 120               Afghanistan          0          0           0           0
# 121                      Iraq          0          0           0       82.15
# 122                Uzbekistan          0          0           0           0
#
# ...

# %%
dfgm.isnull().sum()
# Out:
# Country    0
# 2001       0
# 2002       0
# 2003       0
# 2004       0
# 2005       0
# 2006       0
# 2007       0
# 2008       0
# 2009       0
# 2010       0
# 2011       0
# 2012       0
# 2013       0
# 2014       0
# 2015       0
# 2016       0
# 2017       0
# 2018       0
# 2019       0
# 2020       0
# 2021       0
# dtype: int64

# %%
#Performing data transformation on Table - Gold Reserve in MillionDollars
dfgm = pd.melt(dfgm, id_vars = ["Country"], var_name = "year", value_name = "Million(Dollars)")
dfgm
# Out:
#                        Country  year Million(Dollars)
# 0     United States of America  2001        72,443.00
# 1                      Germany  2001        30,728.00
# 2                       France  2001        26,888.24
# 3                        Italy  2001        21,796.22
# 4                  Switzerland  2001        19,543.95
# ...                        ...   ...              ...
# 2578                Azerbaijan  2021             0.12
# 2579                   Croatia  2021                0
# 2580               Afghanistan  2021         1,269.53
# 2581                      Iraq  2021         5,598.14
# 2582                Uzbekistan  2021        21,020.09
#
# [2583 rows x 3 columns]

# %%
#Saving the gold reserves in million dollars csv in the directory.
dfgm.to_csv("dfgm.csv", index = False)

# %%
#Joining the tables in pandas before loading them in tableau - Step taken for Dashboard Optimization
dfgold = pd.merge(left = dfgt, right = dfgm, how = 'inner')
dfgold
# Out:
#                        Country  year Reserves(Ton) Million(Dollars)
# 0     United States of America  2001      8,149.05        72,443.00
# 1                      Germany  2001      3,456.56        30,728.00
# 2                       France  2001      3,024.63        26,888.24
# 3                        Italy  2001      2,451.84        21,796.22
# 4                  Switzerland  2001      2,198.48        19,543.95
# ...                        ...   ...           ...              ...
# 2578                Azerbaijan  2021             0             0.12
# 2579                   Croatia  2021             0                0
# 2580               Afghanistan  2021         21.87         1,269.53
# 2581                      Iraq  2021         96.42         5,598.14
# 2582                Uzbekistan  2021        362.04        21,020.09
#
# [2583 rows x 4 columns]

# %%
#Saving the joined gold table in the directory.
dfgold.to_csv("dfgold.csv", index = False)

# %%
#Accesing the file and storing it as a csv for further operations - Crude Oil Prices
dfc = pd.read_csv("/content/drive/MyDrive/Predictive_Project/CRUDE_OIL_PRICES.csv")
dfc.head(3)
# Out:
#    Year  price
# 0  2021  70.91
# 1  2020  41.84
# 2  2019  64.21

# %%
#Saving the oil price table in directory
dfc.to_csv("dfc.csv", index = False)

# %%
#Accesing the file and storing it as a csv for further operations - Silver Prices
dfs = pd.read_csv("/content/drive/MyDrive/Predictive_Project/Silver Prices.csv")
dfs
# Out:
#     year  avg_closing_price_silver
# 0   2022                     21.80
# 1   2021                     25.14
# 2   2020                     20.69
# 3   2019                     16.22
# 4   2018                     15.71
# 5   2017                     17.07
# 6   2016                     17.17
# 7   2015                     15.66
# 8   2014                     19.07
# 9   2013                     23.79
# 10  2012                     31.15
# 11  2011                     35.12
# 12  2010                     20.19
# 13  2009                     14.67
# 14  2008                     14.99
# 15  2007                     13.38
# 16  2006                     11.55
# 17  2005                      7.31
# 18  2004                      6.66
# 19  2003                      4.88
# 20  2002                      4.60
# 21  2001                      4.37
# 22  2000                      4.95
# 23  1999                      5.22
# 24  1998                      5.54
# 25  1997                      4.90
# ...

# %%
#Saving the silver price table in directory
dfs.to_csv("dfs.csv", index = False)

# %%
#Accesing the file and storing it as a csv for further operations - Gold Prices
dfg = pd.read_csv("/content/drive/MyDrive/Predictive_Project/Gold Prices.csv")
dfg
# Out:
#     year  avg_closing_price_gold
# 0   2022                 1818.05
# 1   2021                 1798.89
# 2   2020                 1773.73
# 3   2019                 1393.34
# 4   2018                 1268.93
# 5   2017                 1260.39
# 6   2016                 1251.92
# 7   2015                 1158.86
# 8   2014                 1266.06
# 9   2013                 1409.51
# 10  2012                 1668.86
# 11  2011                 1573.16
# 12  2010                 1226.66
# 13  2009                  973.66
# 14  2008                  872.37
# 15  2007                  696.43
# 16  2006                  604.34
# 17  2005                  444.99
# 18  2004                  409.53
# 19  2003                  363.83
# 20  2002                  310.08
# 21  2001                  271.19
# 22  2000                  279.29
# 23  1999                  278.86
# 24  1998                  294.12
# 25  1997                  331.00
# 26  1996                  387.73
# ...

# %%
#Saving the gold price table in directory
dfg.to_csv("dfg.csv", index = False)

# %%
#Accesing the file and storing it as a csv for further operations - NASDAQ
dfn = pd.read_csv("/content/drive/MyDrive/Predictive_Project/NASDAQ.csv")
dfn
# Out:
#     year  avg_closing_points_nasdaq
# 0   2022                   12599.35
# 1   2021                   14371.46
# 2   2020                   10201.51
# 3   2019                    7940.36
# 4   2018                    7425.96
# 5   2017                    6235.30
# 6   2016                    4987.79
# 7   2015                    4945.55
# 8   2014                    4375.10
# 9   2013                    3541.29
# 10  2012                    2965.74
# 11  2011                    2677.44
# 12  2010                    2349.89
# 13  2009                    1845.39
# 14  2008                    2161.68
# 15  2007                    2578.47
# 16  2006                    2263.41
# 17  2005                    2099.32
# 18  2004                    1986.53
# 19  2003                    1647.17
# 20  2002                    1539.73
# 21  2001                    2029.61
# 22  2000                    3783.67
# 23  1999                    2728.15
# 24  1998                    1794.91
# ...

# %%
#Saving the nasdaq table in directory
dfn.to_csv("dfn.csv", index = False)

# %%
#Accesing the file and storing it as a csv for further operations - S&P
dfsp = pd.read_csv("/content/drive/MyDrive/Predictive_Project/S&P 500 Index.csv")
dfsp
# Out:
#     year  sp_500_index_points_closing
# 0   2022                      4155.16
# 1   2021                      4273.41
# 2   2020                      3217.86
# 3   2019                      2913.36
# 4   2018                      2746.21
# ..   ...                          ...
# 90  1932                         6.92
# 91  1931                        13.66
# 92  1930                        21.00
# 93  1929                        26.19
# 94  1928                        19.94
#
# [95 rows x 2 columns]

# %%
#Saving the s&p500 table in directory
dfsp.to_csv("dfsp.csv", index = False)

# %%
#Accesing the file and storing it as a csv for further operations - house_us
dfhu = pd.read_csv("/content/drive/MyDrive/Predictive_Project/Average_price_us.csv")
dfhu.head(3)
# Out:
#    year  avg_house_price_us
# 0  2001              211000
# 1  2001              211200
# 2  2001              207800

# %%
g = dfhu.groupby('year')
g

# %%
dfhu = g.mean()
dfhu
# Out:
#       avg_house_price_us
# year
# 2001            211050.0
# 2002            226700.0
# 2003            244550.0
# 2004            272125.0
# 2005            291275.0
# 2006            303900.0
# 2007            309800.0
# 2008            289075.0
# 2009            269350.0
# 2010            272025.0
# 2011            264600.0
# 2012            288225.0
# 2013            321650.0
# 2014            345450.0
# 2015            350450.0
# 2016            359650.0
# 2017            381150.0
# 2018            382475.0
# 2019            379875.0
# 2020            389800.0
# 2021            457375.0
# 2022            519550.0

# %%
#Saving the house_price_us table in directory
dfhu.to_csv("dfhu.csv", index = False)

# %%
#Accesing the file and storing it as a csv for further operations - house_ca
dfhc = pd.read_csv("/content/drive/MyDrive/Predictive_Project/Residential_Canada.csv")
dfhc.head(3)
# Out:
#    year  avg_house_price_canada
# 0  2005                  229417
# 1  2005                  238564
# 2  2005                  243828

# %%
k = dfhc.groupby('year')
k

# %%
dfhc = k.mean()
dfhc
# Out:
#       avg_house_price_canada
# year
# 2005           248614.000000
# 2006           275996.833333
# 2007           306635.250000
# 2008           302397.916667
# 2009           317268.916667
# 2010           338652.166667
# 2011           360954.083333
# 2012           361953.750000
# 2013           382333.333333
# 2014           407448.750000
# 2015           440308.166667
# 2016           486989.333333
# 2017           505861.500000
# 2018           488982.166667
# 2019           500253.166667
# 2020           557643.333333
# 2021           686102.333333
# 2022           710150.333333

# %%
#Saving the house_price_ca table in directory
dfhc.to_csv("dfhc.csv", index = False)

# %%
#Joining the tables in pandas before loading them in tableau - Step taken for Dashboard Optimization (gold and silver - gs)
dfgs = pd.merge(dfg, dfs, how = "outer", on ="year")
dfgs
# Out:
#     year  avg_closing_price_gold  avg_closing_price_silver
# 0   2022                 1818.05                     21.80
# 1   2021                 1798.89                     25.14
# 2   2020                 1773.73                     20.69
# 3   2019                 1393.34                     16.22
# 4   2018                 1268.93                     15.71
# 5   2017                 1260.39                     17.07
# 6   2016                 1251.92                     17.17
# 7   2015                 1158.86                     15.66
# 8   2014                 1266.06                     19.07
# 9   2013                 1409.51                     23.79
# 10  2012                 1668.86                     31.15
# 11  2011                 1573.16                     35.12
# 12  2010                 1226.66                     20.19
# 13  2009                  973.66                     14.67
# 14  2008                  872.37                     14.99
# ...

# %%
#Joining the tables in pandas before loading them in tableau - Step taken for Dashboard Optimization (gs and nasdaq - gsn)
dfgsn = pd.merge(dfgs, dfn, how = "outer")
dfgsn
# Out:
#     year  avg_closing_price_gold  avg_closing_price_silver  \
# 0   2022                 1818.05                     21.80
# 1   2021                 1798.89                     25.14
# 2   2020                 1773.73                     20.69
# 3   2019                 1393.34                     16.22
# 4   2018                 1268.93                     15.71
# 5   2017                 1260.39                     17.07
# 6   2016                 1251.92                     17.17
# 7   2015                 1158.86                     15.66
# 8   2014                 1266.06                     19.07
# 9   2013                 1409.51                     23.79
# 10  2012                 1668.86                     31.15
# 11  2011                 1573.16                     35.12
# 12  2010                 1226.66                     20.19
# 13  2009                  973.66                     14.67
# 14  2008                  872.37                     14.99
# ...

# %%
#Joining the tables in pandas before loading them in tableau - Step taken for Dashboard Optimization (gsn and s&p - gsns)
dfgsns = pd.merge(dfgsn, dfsp, how = "outer")
dfgsns
# Out:
#     year  avg_closing_price_gold  avg_closing_price_silver  \
# 0   2022                 1818.05                     21.80
# 1   2021                 1798.89                     25.14
# 2   2020                 1773.73                     20.69
# 3   2019                 1393.34                     16.22
# 4   2018                 1268.93                     15.71
# ..   ...                     ...                       ...
# 90  1932                     NaN                       NaN
# 91  1931                     NaN                       NaN
# 92  1930                     NaN                       NaN
# 93  1929                     NaN                       NaN
# 94  1928                     NaN                       NaN
#
#     avg_closing_points_nasdaq  sp_500_index_points_closing
# 0                    12599.35                      4155.16
# 1                    14371.46                      4273.41
# 2                    10201.51                      3217.86
# ...

# %%
#Renaming columns in the crude oil database, so that pd.merge error(no common columns found can be resolved)
dfc.rename(columns = {'Year':'year', 'price':'oil_price'}, inplace = True)

# %%
#joining - combined(gold, silver, nasdaq, s&p) database with the oil database
dfgsnso = pd.merge(dfgsns, dfc, how = "outer", on = "year")
dfgsnso
# Out:
#      year  avg_closing_price_gold  avg_closing_price_silver  \
# 0    2022                 1818.05                     21.80
# 1    2021                 1798.89                     25.14
# 2    2020                 1773.73                     20.69
# 3    2019                 1393.34                     16.22
# 4    2018                 1268.93                     15.71
# ..    ...                     ...                       ...
# 157  1865                     NaN                       NaN
# 158  1864                     NaN                       NaN
# 159  1863                     NaN                       NaN
# 160  1862                     NaN                       NaN
# 161  1861                     NaN                       NaN
#
#      avg_closing_points_nasdaq  sp_500_index_points_closing  oil_price
# 0                     12599.35                      4155.16        NaN
# 1                     14371.46                      4273.41      70.91
# ...

# %%
#Renaming columns in the house_price_us database, so that pd.merge error(no common columns found can be resolved)
#dfhu.rename(columns = {'Year':'yr'}, inplace = True)

# %%
dfhu.head(3)
# Out:
#       avg_house_price_us
# year
# 2001            211050.0
# 2002            226700.0
# 2003            244550.0

# %%
#joining - combined(gold, silver, nasdaq, s&p, oil) database with the house_us database
dfgsnsou = pd.merge(dfgsnso, dfhu, how = "outer", on = "year")
dfgsnsou
# Out:
#      year  avg_closing_price_gold  avg_closing_price_silver  \
# 0    2022                 1818.05                     21.80
# 1    2021                 1798.89                     25.14
# 2    2020                 1773.73                     20.69
# 3    2019                 1393.34                     16.22
# 4    2018                 1268.93                     15.71
# ..    ...                     ...                       ...
# 157  1865                     NaN                       NaN
# 158  1864                     NaN                       NaN
# 159  1863                     NaN                       NaN
# 160  1862                     NaN                       NaN
# 161  1861                     NaN                       NaN
#
#      avg_closing_points_nasdaq  sp_500_index_points_closing  oil_price  \
# 0                     12599.35                      4155.16        NaN
# 1                     14371.46                      4273.41      70.91
# ...

# %%
#joining - combined(gold, silver, nasdaq, s&p, oil, house_us) database with the house_canada database
dfgsnsouc = pd.merge(dfgsnsou, dfhc, how = "outer", on = "year")
dfgsnsouc
# Out:
#      year  avg_closing_price_gold  avg_closing_price_silver  \
# 0    2022                 1818.05                     21.80
# 1    2021                 1798.89                     25.14
# 2    2020                 1773.73                     20.69
# 3    2019                 1393.34                     16.22
# 4    2018                 1268.93                     15.71
# ..    ...                     ...                       ...
# 157  1865                     NaN                       NaN
# 158  1864                     NaN                       NaN
# 159  1863                     NaN                       NaN
# 160  1862                     NaN                       NaN
# 161  1861                     NaN                       NaN
#
#      avg_closing_points_nasdaq  sp_500_index_points_closing  oil_price  \
# 0                     12599.35                      4155.16        NaN
# 1                     14371.46                      4273.41      70.91
# ...

# %%
#Saving the final joined csv  in directory
dfgsnsouc.to_csv("df_final_table.csv", index = False)
